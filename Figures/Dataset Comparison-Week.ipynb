# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read saved csv files
TrainVal     = pd.read_csv('01TrainVal.csv')
TrainVal['index'] = pd.to_datetime(TrainVal['index'])
TrainVal.rename(columns = {'index':'Timestamp'}, inplace=True)

# %% [markdown]
# ### Stockton

# %%
TrainVal[864:10944]
# Out:
#                 Timestamp     f1     f2     f3     f4     f5    f6    f7
# 864   2019-03-04 00:00:00   62.0   58.0   53.0   69.0   68.0  44.0  42.0
# 865   2019-03-04 00:05:00   83.0   86.0   86.0   93.0   87.0  42.0  46.0
# 866   2019-03-04 00:10:00   95.0  102.0   74.0  107.0   96.0  55.0  59.0
# 867   2019-03-04 00:15:00   63.0   77.0   80.0   91.0   81.0  42.0  47.0
# 868   2019-03-04 00:20:00   65.0   65.0   73.0   84.0   77.0  43.0  45.0
# ...                   ...    ...    ...    ...    ...    ...   ...   ...
# 10939 2019-04-07 23:35:00   93.0  103.0  104.0   86.0   90.0  58.0  57.0
# 10940 2019-04-07 23:40:00  135.0  121.0  140.0  114.0  129.0  92.0  68.0
# 10941 2019-04-07 23:45:00  112.0  106.0  106.0  106.0  117.0  78.0  64.0
# 10942 2019-04-07 23:50:00  111.0  116.0  121.0  105.0  127.0  88.0  84.0
# 10943 2019-04-07 23:55:00  105.0  116.0  117.0   99.0  101.0  64.0  62.0
#
# [10080 rows x 8 columns]

# %%
TrainVal[864:10944]['f5']
# Out:
# 864       68.0
# 865       87.0
# 866       96.0
# 867       81.0
# 868       77.0
#          ...
# 10939     90.0
# 10940    129.0
# 10941    117.0
# 10942    127.0
# 10943    101.0
# Name: f5, Length: 10080, dtype: float64

# %%
df = TrainVal[864:10944]['f5'].to_numpy()

# %%
df = df.reshape(35,288)

# %%
df
# Out:
# array([[ 68. ,  87. ,  96. , ..., 103. ,  97. ,  78. ],
#        [112. ,  95. , 125. , ...,  98. , 114. ,  98. ],
#        [ 97. , 116. , 102. , ..., 104. , 101. , 109. ],
#        ...,
#        [116. ,  89. , 125. , ..., 163. , 163. , 131. ],
#        [132. , 147. , 151. , ..., 134. , 155. , 114. ],
#        [124.5, 135. , 130. , ..., 117. , 127. , 101. ]])

# %%
df1 = pd.DataFrame(df.T, columns=['Mon','Tue','Wed','Thu','Fri','Sat','Sun']*5)

# %%
df1
# Out:
#        Mon    Tue    Wed    Thu    Fri    Sat    Sun    Mon    Tue    Wed  \
# 0     68.0  112.0   97.0   99.0  102.0  122.0  106.0   82.0  122.0   97.0
# 1     87.0   95.0  116.0   84.0  105.0  147.0  104.0   89.0  122.0  112.0
# 2     96.0  125.0  102.0  104.0  103.0  114.0  124.0   86.0  117.0   99.0
# 3     81.0  103.0  105.0   92.0  117.0  127.0  102.0   80.0  100.0  105.0
# 4     77.0  106.0   90.0   79.0   93.0  111.0  111.0   86.0   77.0   92.0
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 283  118.0   99.0   97.0  108.0  163.0  124.0  123.0  138.0  104.0  111.0
# 284  105.0   99.0  110.0  101.0  150.0  123.0  125.0  124.0  108.0  125.0
# 285  103.0   98.0  104.0  128.0  172.0  105.0  136.0  120.0  105.0  107.0
# 286   97.0  114.0  101.0  104.0  120.0  131.0  107.0  110.0  109.0  127.0
# 287   78.0   98.0  109.0   79.0  140.0  101.0   92.0   93.0   94.0  123.0
#
#      ...    Fri    Sat    Sun    Mon    Tue    Wed    Thu    Fri    Sat    Sun
# 0    ...  113.0  167.0  116.0  103.0  120.0  113.0  139.0  116.0  132.0  124.5
# 1    ...  152.0  178.0  170.0  108.0  118.0  130.0  111.0   89.0  147.0  135.0
# 2    ...  138.0  205.0  123.0   85.0  100.0  105.0  125.0  125.0  151.0  130.0
# 3    ...  121.0  136.0  108.0   95.0   87.0   96.0  106.0  110.0  122.0  138.0
# 4    ...   83.0  141.0  143.0  108.0   70.0   83.0  103.0   91.0  121.0  111.0
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 283  ...  205.0  157.0  160.0  103.0  112.0  135.0  118.0  143.0  135.0   90.0
# 284  ...  176.0  132.0  140.0  126.0  128.0  129.0  111.0  153.0  147.0  129.0
# 285  ...  168.0  131.0  110.0  113.0  117.0  160.0  110.0  163.0  134.0  117.0
# 286  ...  173.0  141.0  115.0  115.0   94.0  130.0  101.0  163.0  155.0  127.0
# 287  ...  168.0  151.0  109.0  104.0  107.0   84.0  130.0  131.0  114.0  101.0
#
# [288 rows x 35 columns]

# %% [markdown]
# ### Oakland

# %%
TrainVal    = pd.read_csv('0TrainVal.csv',index_col=0,parse_dates=True)

# %%
TrainVal[1152:11232]
# Out:
#                        f1    f2    f3     f4    f5    f6
# Timestamp
# 2017-08-21 00:00:00  45.0  42.0  29.2   88.0  34.0  40.0
# 2017-08-21 00:05:00  41.0  42.0  36.2   89.0  33.0  49.0
# 2017-08-21 00:10:00  39.0  33.0   8.0   85.0  12.0  40.0
# 2017-08-21 00:15:00  35.0  26.0  10.0   80.0  34.0  48.0
# 2017-08-21 00:20:00  33.0  31.0  21.0   85.0  27.0  55.0
# ...                   ...   ...   ...    ...   ...   ...
# 2017-09-24 23:35:00  45.0  44.0  84.0  125.0  60.0  27.0
# 2017-09-24 23:40:00  48.0  50.0  64.0  121.0  60.0  26.0
# 2017-09-24 23:45:00  39.0  36.0   4.0   99.0  48.0  23.0
# 2017-09-24 23:50:00  38.0  34.0  59.0  101.0  46.0  22.0
# 2017-09-24 23:55:00  33.0  29.0  18.0  102.0  51.0  22.0
#
# [10080 rows x 6 columns]

# %%
TrainVal[1152:11232]['f4']
# Out:
# Timestamp
# 2017-08-21 00:00:00     88.0
# 2017-08-21 00:05:00     89.0
# 2017-08-21 00:10:00     85.0
# 2017-08-21 00:15:00     80.0
# 2017-08-21 00:20:00     85.0
#                        ...
# 2017-09-24 23:35:00    125.0
# 2017-09-24 23:40:00    121.0
# 2017-09-24 23:45:00     99.0
# 2017-09-24 23:50:00    101.0
# 2017-09-24 23:55:00    102.0
# Name: f4, Length: 10080, dtype: float64

# %%
df = TrainVal[1152:11232]['f4'].to_numpy()

# %%
df
# Out:
# array([ 88.,  89.,  85., ...,  99., 101., 102.])

# %%
df = df.reshape(35,288)

# %%
df
# Out:
# array([[ 88.,  89.,  85., ..., 121., 105., 102.],
#        [ 90., 123., 107., ...,  96., 127., 115.],
#        [ 72.,  82., 109., ..., 148., 130., 106.],
#        ...,
#        [148., 162., 160., ..., 185., 200., 228.],
#        [202., 224., 208., ..., 133., 181., 155.],
#        [170., 146., 157., ...,  99., 101., 102.]])

# %%
df2 = pd.DataFrame(df.T, columns=['Mon','Tue','Wed','Thu','Fri','Sat','Sun']*5)

# %%
df2
# Out:
#        Mon    Tue    Wed    Thu    Fri    Sat    Sun    Mon    Tue    Wed  \
# 0     88.0   90.0   72.0   99.0  121.0  170.0  174.0   79.0   88.0  114.0
# 1     89.0  123.0   82.0   89.0  151.0  168.0  150.0   76.0   98.0   94.0
# 2     85.0  107.0  109.0   92.0  120.0  149.0  146.0   76.0   81.0   98.0
# 3     80.0   91.0   85.0  110.0   80.0  174.0  165.0   85.0   68.0  110.0
# 4     85.0   82.0   96.0   92.0   92.0  164.0  152.0   61.0   81.0   97.0
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 283  127.0  159.0  146.0  153.0  171.0  205.0  110.0  118.0  139.0  122.0
# 284  138.0  135.0  157.0  151.0  183.0  221.0  111.0   95.0  118.0  107.0
# 285  121.0   96.0  148.0  149.0  178.0  172.0   84.0   84.0   96.0   91.0
# 286  105.0  127.0  130.0  108.0  181.0  158.0   87.0   76.0  117.0   65.0
# 287  102.0  115.0  106.0  164.0  180.0  189.0   97.0   82.0   94.0   94.0
#
#      ...    Fri    Sat    Sun    Mon    Tue    Wed    Thu    Fri    Sat    Sun
# 0    ...  116.0  175.0  161.0   86.0   77.0  113.0   21.0  148.0  202.0  170.0
# 1    ...  147.0  199.0  160.0   82.0   91.0   88.0   21.0  162.0  224.0  146.0
# 2    ...  147.0  168.0  156.0   76.0   79.0   82.0   21.0  160.0  208.0  157.0
# 3    ...  126.0  169.0  161.0   72.0   74.0   93.0   21.0  127.0  161.0  185.0
# 4    ...  133.0  195.0  155.0   82.0   66.0   97.0   21.0  132.0  178.0  173.0
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 283  ...  218.0  168.0  106.0  108.0  125.0   21.0  173.0  181.0  208.0  125.0
# 284  ...  203.0  192.0  105.0   90.0  120.0   21.0  195.0  195.0  168.0  121.0
# 285  ...  194.0  164.0  117.0   81.0  140.0   21.0  169.0  185.0  133.0   99.0
# 286  ...  180.0  182.0   75.0   77.0  108.0   21.0  135.0  200.0  181.0  101.0
# 287  ...  163.0  169.0   86.0   81.0   81.0   21.0  132.0  228.0  155.0  102.0
#
# [288 rows x 35 columns]

# %% [markdown]
# ## Plots

# %%
plt.figure(figsize=(12,4), dpi=300)

ticks = [0, 36, 72, 108, 144, 180, 216, 252, 288]
hmap = sns.heatmap(df1,
                  xticklabels=True,
                  cbar=True,
                  cbar_kws={'fraction' : 0.01}, # shrink colour bar
                  cmap='viridis',
                  robust=True,
                 )

for i in ticks:
    hmap.axhline(i, color='white', lw=1)
for j in range(0,df1.shape[1],7):
    hmap.axvline(j, color='white', lw=3)
for j in range(0,df1.shape[1],1):
    hmap.axvline(j, color='white', lw=1)
    
    
#hmap.set_xticklabels(hmap.get_xticklabels(), rotation=90);
hmap.set_yticks([0, 36, 72, 108, 144, 180, 216, 252, 288]);
hmap.set_yticklabels(['00:00', '03:00', '06:00', '09:00', '12:00', '15:00', '18:00', '21:00','00:00']);
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,4), dpi=300)

ticks = [0, 36, 72, 108, 144, 180, 216, 252, 288]
hmap = sns.heatmap(df2,
                  xticklabels=True,
                  cbar=True,
                  cbar_kws={'fraction' : 0.01}, # shrink colour bar
                  cmap='viridis',
                  robust=True,
                 )

for i in ticks:
    hmap.axhline(i, color='white', lw=1)
for j in range(0,df2.shape[1],7):
    hmap.axvline(j, color='white', lw=3)
for j in range(0,df2.shape[1],1):
    hmap.axvline(j, color='white', lw=1)
    
    
#hmap.set_xticklabels(hmap.get_xticklabels(), rotation=90);
hmap.set_yticks([0, 36, 72, 108, 144, 180, 216, 252, 288]);
hmap.set_yticklabels(['00:00', '03:00', '06:00', '09:00', '12:00', '15:00', '18:00', '21:00','00:00']);
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12,10), dpi=300)

ticks = [0, 36, 72, 108, 144, 180, 216, 252, 288]
xtiks = [k+0.5 for k in range(0,35)]
xlbs = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']*5

a = sns.heatmap( 
            df1,
            xticklabels=False,
            cbar=False,
            cbar_kws={'fraction' : 0.01,
                    'label': 'flow (veh/5-Min)'}, # shrink colour bar
            cmap='viridis',
            robust=True,
            ax=ax[0],
            )

for i in ticks:
    ax[0].axhline(i, color='white', lw=1)
for j in range(0,df1.shape[1],7):
    ax[0].axvline(j, color='white', lw=3)
for j in range(0,df1.shape[1],1):
    ax[0].axvline(j, color='white', lw=1)
    

b = sns.heatmap(
            df2,
            xticklabels=False,
            cbar=False,
            cbar_kws={'fraction' : 0.01,
                    'label': 'flow (veh/5-Min)'}, # shrink colour bar
            cmap='viridis',
            robust=True,
            ax=ax[1],
            )
    
for i in ticks:
    ax[1].axhline(i, color='white', lw=1)
for j in range(0,df2.shape[1],7):
    ax[1].axvline(j, color='white', lw=3)
for j in range(0,df2.shape[1],1):
    ax[1].axvline(j, color='white', lw=1)


cmap = mpl.cm.viridis
norm = mpl.colors.Normalize(vmin=0, vmax=500)

cbar = fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap), ax = ax, label='flow (veh/5-Min)', shrink=0.6)

ax[0].set_xticks(xtiks)
ax[0].set_xticklabels(xlbs, rotation=90, va='center') #, rotation_mode='default')
ax[0].set_yticks([0, 36, 72, 108, 144, 180, 216, 252, 288]);
ax[0].set_yticklabels(['00:00', '03:00', '06:00', '09:00', '12:00', '15:00', '18:00', '21:00','00:00']);
ax[0].tick_params(which='both',labelsize= 15)
ax[0].set_ylabel("")
ax[0].set_xlabel("")

# Fixing the figure issue
import matplotlib.transforms
# Create offset transform by 5 points in x direction
dx = 0/72.; dy = -15/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax[0].xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)


ax[1].set_xticks(xtiks)
ax[1].xaxis.tick_top()
ax[1].set_yticks([0, 36, 72, 108, 144, 180, 216, 252, 288]);
ax[1].set_yticklabels(['00:00', '03:00', '06:00', '09:00', '12:00', '15:00', '18:00', '21:00','00:00']);
ax[1].tick_params(which='both',labelsize= 15)
ax[1].set_ylabel("")
ax[1].set_xlabel("")
ax[1].figure.axes[-1].yaxis.label.set_size(15)
ax[1].figure.axes[-2].yaxis.label.set_size(15)
ax[1].figure.axes[-1].xaxis.label.set_size(15)
cbar.ax.tick_params(labelsize= 15);

#plt.tight_layout()
plt.plot()
plt.show()

fig.savefig('Comparison1.png')
