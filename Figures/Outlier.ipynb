# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from colors import *

# %%
# Read saved csv files
TrainVal_s  = pd.read_csv('C:\\Users\\esugom\\OneDrive - Coventry University\\CodePhD\\Stockton\\00TrainVal.csv', index_col=0)
TrainVal_o  = pd.read_csv('C:\\Users\\esugom\\OneDrive - Coventry University\\CodePhD\\Oakland\\00TrainVal.csv', index_col=0)

# %%
plt.rcParams.update({'font.size': 16})

# %%
c = [BLUE1, BLUE2, BLUE3, BLUE4]

# %% [markdown]
# **************
#
# # Section I : Data Check
#
# ---------------

# %%
TrainVal_s
# Out:
#                         f1     f2     f3     f4     f5     f6    f7
# 2019-03-01 00:00:00  104.0   98.0  132.0  125.0  128.0   38.0  45.0
# 2019-03-01 00:05:00  100.0   95.0  135.0  125.0  119.0   72.0  77.0
# 2019-03-01 00:10:00  110.0  124.0  132.0  112.0  118.0   73.0  73.0
# 2019-03-01 00:15:00  110.0  102.0  103.0  100.0  106.0   88.0  90.0
# 2019-03-01 00:20:00  101.0   98.0  117.0  114.0  109.0   66.0  62.0
# ...                    ...    ...    ...    ...    ...    ...   ...
# 2019-06-30 23:35:00  141.0  143.0  150.0  142.0  153.0  110.0  84.0
# 2019-06-30 23:40:00  132.0  128.0  139.0  116.0  114.0   98.0  89.0
# 2019-06-30 23:45:00  106.0  111.0  123.0  127.0  146.0   94.0  85.0
# 2019-06-30 23:50:00  137.0  140.0  141.0  103.0  124.0  109.0  95.0
# 2019-06-30 23:55:00  125.0  114.0  136.0  128.0  130.0  100.0  98.0
#
# [35136 rows x 7 columns]

# %%
TrainVal_o
# Out:
#                  Timestamp    f1    f2    f3     f4    f5     f6
# 0      2017-08-17 00:00:00  46.0  38.0   0.0  121.0  65.0   87.0
# 1      2017-08-17 00:05:00  37.0  37.0   0.0  109.0  60.0   90.0
# 2      2017-08-17 00:10:00  45.0  43.0   0.0  105.0  61.0   87.0
# 3      2017-08-17 00:15:00  38.0  35.0   0.0  109.0  68.0  102.0
# 4      2017-08-17 00:20:00  36.0  30.0  30.0   94.0  61.0   93.0
# ...                    ...   ...   ...   ...    ...   ...    ...
# 57595  2018-03-04 23:35:00  46.0  41.0  70.0  118.0  64.0   52.0
# 57596  2018-03-04 23:40:00  39.0  37.0  53.0   93.0  43.0   28.0
# 57597  2018-03-04 23:45:00  48.0  54.0  45.0   94.0  39.0   16.0
# 57598  2018-03-04 23:50:00  43.0  43.0  57.0  112.0  39.0   11.0
# 57599  2018-03-04 23:55:00  46.0  38.0  58.0   98.0  42.0   12.0
#
# [57600 rows x 7 columns]

# %% [markdown]
# -----------
#
# # 2) Check for outliers
#
# ----------

# %%
f, ax = plt.subplots(figsize=(5, 7.5), dpi=300)

ax = sns.boxplot(data=TrainVal_s, notch=True, orient="h", medianprops={"color": "salmon"}, 
                boxprops=dict(linewidth=1, facecolor='w', edgecolor='k', alpha=1))


ax.set_ylabel('Location')
ax.set_xlabel('Flow (veh/5-Min)')

ax.set_yticklabels(['$S_{1}$','$S_{2}$','$S_{3}$','$S_{4}$','$S_{5}$','$S_{6}$','$S_{7}$']);
ax.invert_yaxis()

# %%
f, ax = plt.subplots(figsize=(5, 7.5), dpi=300)

ax = sns.boxplot(data=TrainVal_o, notch=True, orient="h", medianprops={"color": "salmon"}, 
                boxprops=dict(linewidth=1, facecolor='w', edgecolor='k', alpha=1))


ax.set_ylabel('Location')
ax.set_xlabel('Flow (veh/5-Min)')

ax.set_yticklabels(['$S_{1}$','$S_{2}$','$S_{3}$','$S_{4}$','$S_{5}$','$S_{6}$']);
ax.invert_yaxis()
