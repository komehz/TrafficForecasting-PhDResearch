# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Train DataSet

# %%
# Read saved csv files
March = pd.read_csv('03March.csv',header=None)
April = pd.read_csv('04April.csv',header=None)
May   = pd.read_csv('05May.csv',header=None)
June  = pd.read_csv('06June.csv',header=None)

# %%
# Trim the data (first 17 columns)
March = March.iloc[:,0:17]
April = April.iloc[:,0:17]
May   = May.iloc[:,0:17]
June  = June.iloc[:,0:17]

# %%
# Define dataframe header
columns = ['Timestamp','Station','District','Freeway','DoT','Lane Type','Station Length','Samples', '% Obs',
          'Total flow','Avg Occ','Ave Speed','Lane N Samples','Lane N Flow','Lane N Avg Occ','Lane N Avg Speed','Lane N obs']

# %%
# Input the header defined above
March.columns = columns
April.columns = columns
May.columns   = columns
June.columns  = columns

# %%
May.head()
# Out:
#              Timestamp  Station  District  Freeway DoT Lane Type  \
# 0  05/01/2019 00:00:00  1007410        10        5   N        ML
# 1  05/01/2019 00:00:00  1016610        10        5   N        ML
# 2  05/01/2019 00:00:00  1021310        10        5   N        ML
# 3  05/01/2019 00:00:00  1021410        10        5   N        ML
# 4  05/01/2019 00:00:00  1021510        10        5   N        ML
#
#    Station Length  Samples  % Obs  Total flow  Avg Occ  Ave Speed  \
# 0           0.501       36    100       116.0   0.0234       71.1
# 1           0.612       30    100       102.0   0.0268       63.8
# 2           0.726       27     67        92.0   0.0277       64.6
# 3           0.487        0      0        94.0   0.0297       63.2
# 4           0.450        0      0       114.0   0.0278       65.7
#
#    Lane N Samples  Lane N Flow  Lane N Avg Occ  Lane N Avg Speed  Lane N obs
# 0             9.0         38.0          0.0231              78.4           1
# 1            10.0         38.0          0.0215              74.8           1
# 2             9.0         31.0          0.0210              72.7           1
# 3             0.0         33.0          0.0226              68.6           0
# 4             0.0         63.0          0.0227              69.2           0

# %%
March.tail()
# Out:
#                  Timestamp   Station  District  Freeway DoT Lane Type  \
# 98071  03/31/2019 23:55:00   1022210        10        5   N        ML
# 98072  03/31/2019 23:55:00   1027410        10        5   N        ML
# 98073  03/31/2019 23:55:00   1096310        10        5   N        ML
# 98074  03/31/2019 23:55:00   1096710        10        5   N        ML
# 98075  03/31/2019 23:55:00  10115310        10        5   N        ML
#
#        Station Length  Samples  % Obs  Total flow  Avg Occ  Ave Speed  \
# 98071           1.497        0      0         9.0   0.0036       67.9
# 98072           0.249        0      0        77.0   0.0219       65.8
# 98073           0.669       30    100       123.0   0.0260       70.0
# 98074           0.249       30    100       118.0   0.0276       68.0
# 98075           0.730       24    100        66.0   0.0220       59.1
#
#        Lane N Samples  Lane N Flow  Lane N Avg Occ  Lane N Avg Speed  \
# 98071             0.0          2.0          0.0026              71.9
# 98072             0.0         41.0          0.0226              68.5
# 98073            10.0         43.0          0.0223              71.6
# 98074            10.0         41.0          0.0244              71.8
# 98075             8.0         11.0          0.0060              71.6
#
#        Lane N obs
# 98071           0
# 98072           0
# 98073           1
# 98074           1
# 98075           1

# %%
df = pd.concat([March,April,May,June],ignore_index=True)

# %%
len(df)
# Out:
# 385624

# %%
# Pass a list of column names (the important variables)
df = df[['Timestamp','Station','Total flow']]

# %%
df
# Out:
#                   Timestamp   Station  Total flow
# 0       03/01/2019 00:00:00   1007410       132.0
# 1       03/01/2019 00:00:00   1016610       128.0
# 2       03/01/2019 00:00:00   1021310       187.0
# 3       03/01/2019 00:00:00   1021410       125.0
# 4       03/01/2019 00:00:00   1021510       125.0
# ...                     ...       ...         ...
# 385619  06/30/2019 23:55:00   1022210         9.0
# 385620  06/30/2019 23:55:00   1027410        86.0
# 385621  06/30/2019 23:55:00   1096310       114.0
# 385622  06/30/2019 23:55:00   1096710       125.0
# 385623  06/30/2019 23:55:00  10115310       100.0
#
# [385624 rows x 3 columns]

# %%
# Replace Station ID
mymap = {
            1096710  : 'f1',
            1096310  : 'f2',
            1007410  : 'f3',
            1021310  : 'f4',
            1021410  : 'f5',
            1021510  : 'f6',
            1016610  : 'f7',
            1027410  : 'f8',
            10115310 : 'f9',
            1022010  : 'f10',
            1022210  : 'f11'
        }
df['Station'] = df['Station'].map(mymap)

# %%
df['Station'].value_counts()
# Out:
# f4     35083
# f8     35083
# f7     35083
# f9     35083
# f1     35083
# f6     35083
# f5     35083
# f3     35083
# f2     35083
# f10    35082
# f11    34795
# Name: Station, dtype: int64

# %%
df['Timestamp'].nunique()
# Out:
# 35083

# %%
# Re-arrange the Dataframe to spatio-temporal format
df = df.pivot(index='Timestamp',columns='Station',values='Total flow')

# %%
df.keys()
# Out:
# Index(['f1', 'f10', 'f11', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9'], dtype='object', name='Station')

# %%
# f11 is incomplete so drop it
df.drop(columns = 'f11', inplace = True)

# %%
df
# Out:
# Station                 f1   f10     f2     f3     f4     f5     f6     f7  \
# Timestamp
# 03/01/2019 00:00:00  104.0  45.0   98.0  132.0  187.0  125.0  125.0  128.0
# 03/01/2019 00:05:00  100.0  77.0   95.0  135.0  121.0  118.0  125.0  119.0
# 03/01/2019 00:10:00  110.0  73.0  124.0  132.0  134.0  128.0  112.0  118.0
# 03/01/2019 00:15:00  110.0  90.0  102.0  103.0  127.0  103.0  100.0  106.0
# 03/01/2019 00:20:00  101.0  62.0   98.0  117.0  132.0  111.0  114.0  109.0
# ...                    ...   ...    ...    ...    ...    ...    ...    ...
# 06/30/2019 23:35:00  141.0  84.0  143.0  150.0  134.0  141.0  142.0  153.0
# 06/30/2019 23:40:00  132.0  89.0  128.0  139.0  134.0  117.0  116.0  114.0
# 06/30/2019 23:45:00  106.0  85.0  111.0  123.0  105.0  118.0  127.0  146.0
# 06/30/2019 23:50:00  137.0  95.0  140.0  141.0  137.0  121.0  103.0  124.0
# 06/30/2019 23:55:00  125.0  98.0  114.0  136.0  124.0  129.0  128.0  130.0
#
# Station                f8     f9
# Timestamp
# 03/01/2019 00:00:00  72.0   38.0
# 03/01/2019 00:05:00  73.0   72.0
# 03/01/2019 00:10:00  74.0   73.0
# 03/01/2019 00:15:00  74.0   88.0
# 03/01/2019 00:20:00  71.0   66.0
# ...                   ...    ...
# 06/30/2019 23:35:00  92.0  110.0
# 06/30/2019 23:40:00  82.0   98.0
# 06/30/2019 23:45:00  86.0   94.0
# 06/30/2019 23:50:00  75.0  109.0
# 06/30/2019 23:55:00  86.0  100.0
#
# [35083 rows x 10 columns]

# %%
# Re-arrange spatial columns, so, the data is sequential
df = df[['f1','f2','f3','f4','f5','f6','f7','f8','f9','f10']]
df
# Out:
# Station                 f1     f2     f3     f4     f5     f6     f7    f8  \
# Timestamp
# 03/01/2019 00:00:00  104.0   98.0  132.0  187.0  125.0  125.0  128.0  72.0
# 03/01/2019 00:05:00  100.0   95.0  135.0  121.0  118.0  125.0  119.0  73.0
# 03/01/2019 00:10:00  110.0  124.0  132.0  134.0  128.0  112.0  118.0  74.0
# 03/01/2019 00:15:00  110.0  102.0  103.0  127.0  103.0  100.0  106.0  74.0
# 03/01/2019 00:20:00  101.0   98.0  117.0  132.0  111.0  114.0  109.0  71.0
# ...                    ...    ...    ...    ...    ...    ...    ...   ...
# 06/30/2019 23:35:00  141.0  143.0  150.0  134.0  141.0  142.0  153.0  92.0
# 06/30/2019 23:40:00  132.0  128.0  139.0  134.0  117.0  116.0  114.0  82.0
# 06/30/2019 23:45:00  106.0  111.0  123.0  105.0  118.0  127.0  146.0  86.0
# 06/30/2019 23:50:00  137.0  140.0  141.0  137.0  121.0  103.0  124.0  75.0
# 06/30/2019 23:55:00  125.0  114.0  136.0  124.0  129.0  128.0  130.0  86.0
#
# Station                 f9   f10
# Timestamp
# 03/01/2019 00:00:00   38.0  45.0
# 03/01/2019 00:05:00   72.0  77.0
# 03/01/2019 00:10:00   73.0  73.0
# 03/01/2019 00:15:00   88.0  90.0
# 03/01/2019 00:20:00   66.0  62.0
# ...                    ...   ...
# 06/30/2019 23:35:00  110.0  84.0
# 06/30/2019 23:40:00   98.0  89.0
# 06/30/2019 23:45:00   94.0  85.0
# 06/30/2019 23:50:00  109.0  95.0
# 06/30/2019 23:55:00  100.0  98.0
#
# [35083 rows x 10 columns]

# %%
df.to_csv('000TrainVal.csv')

# %% [markdown]
# # Test DataSet

# %%
# Read CSV data
Weekday   = pd.read_csv('07Weekday.csv',header=None)
Weekend   = pd.read_csv('08Weekend.csv',header=None)

# %%
# Trim the data (first 17 columns only)
Weekday = Weekday.iloc[:,0:17]
Weekend = Weekend.iloc[:,0:17]

# %%
# Rename the columns with the column variable from above
Weekday.columns = columns
Weekend.columns = columns

# %%
# Only these three variables are required
Weekday = Weekday[['Timestamp','Station','Total flow']]
Weekend = Weekend[['Timestamp','Station','Total flow']]

# %%
# Rename the station IDs
Weekday['Station'] = Weekday['Station'].map(mymap)
Weekend['Station'] = Weekend['Station'].map(mymap)

# %%
# Re-arrange the data to time-series format
Weekday = Weekday.pivot(index='Timestamp',columns='Station',values='Total flow')
Weekend = Weekend.pivot(index='Timestamp',columns='Station',values='Total flow')

# %%
# Drop the f11 column (unrequired)
Weekday.drop(columns = 'f11', inplace = True)
Weekend.drop(columns = 'f11', inplace = True)

# %%
# Re-arrange the station header to be sequential
Weekday = Weekday[['f1','f2','f3','f4','f5','f6','f7','f8','f9','f10']]
Weekend = Weekend[['f1','f2','f3','f4','f5','f6','f7','f8','f9','f10']]

# %%
Weekday
# Out:
# Station               f1   f2   f3   f4   f5   f6   f7  f8  f9  f10
# Timestamp
# 08/06/2019 00:00:00   99   98  115   92   97  103  111  66  65   64
# 08/06/2019 00:05:00  104  120  123  112  117  106  111  65  73   69
# 08/06/2019 00:10:00   99  104  118   91   88  117  126  66  75   75
# 08/06/2019 00:15:00  119  119  118  106   99  111  121  77  74   74
# 08/06/2019 00:20:00  105  106  110   90   94   98  105  72  84   72
# ...                  ...  ...  ...  ...  ...  ...  ...  ..  ..  ...
# 08/06/2019 23:35:00  169  185  173  137  129  141  158  87  87   85
# 08/06/2019 23:40:00  132  123  165  137  137  132  141  77  64   69
# 08/06/2019 23:45:00  143  141  135  107  105  142  145  81  86   81
# 08/06/2019 23:50:00   96   95  114  105  103  104  113  76  80   69
# 08/06/2019 23:55:00  112  105  109   97  105  104  105  66  58   59
#
# [288 rows x 10 columns]

# %%
Weekend
# Out:
# Station               f1   f2   f3   f4   f5   f6   f7   f8   f9  f10
# Timestamp
# 08/10/2019 00:00:00  117  134  151  135  150  118  123   93  115   91
# 08/10/2019 00:05:00  149  135  181  159  155  145  157   92   77   72
# 08/10/2019 00:10:00  139  135  157  130  126  106  119   82  101   91
# 08/10/2019 00:15:00  120  112  129  108   97  123  141   77   80   77
# 08/10/2019 00:20:00  129  134  135  126  114  126  135   81   69   64
# ...                  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 08/10/2019 23:35:00  177  188  209  178  163  172  198  118  136  128
# 08/10/2019 23:40:00  183  196  228  186  174  160  187  105  108   98
# 08/10/2019 23:45:00  217  198  197  186  174  177  215  119  141  123
# 08/10/2019 23:50:00  209  219  193  184  155  150  176  108  123  115
# 08/10/2019 23:55:00  198  183  218  195  190  167  200  108  117  109
#
# [288 rows x 10 columns]

# %%
Weekday.to_csv('00Weekday.csv')
Weekend.to_csv('00Weekend.csv')
