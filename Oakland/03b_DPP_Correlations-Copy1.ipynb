# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read saved csv files
TrainVal     = pd.read_csv('0TrainVal.csv',index_col=0,parse_dates=True)

# %%
TrainVal
# Out:
#                        f1    f2    f3     f4    f5     f6
# Timestamp
# 2017-08-17 00:00:00  46.0  38.0  43.9  121.0  65.0   87.0
# 2017-08-17 00:05:00  37.0  37.0  52.9  109.0  60.0   90.0
# 2017-08-17 00:10:00  45.0  43.0  39.0  105.0  61.0   87.0
# 2017-08-17 00:15:00  38.0  35.0  36.2  109.0  68.0  102.0
# 2017-08-17 00:20:00  36.0  30.0  30.0   94.0  61.0   93.0
# ...                   ...   ...   ...    ...   ...    ...
# 2018-03-04 23:35:00  46.0  41.0  70.0  118.0  64.0   52.0
# 2018-03-04 23:40:00  39.0  37.0  53.0   93.0  43.0   28.0
# 2018-03-04 23:45:00  48.0  54.0  45.0   94.0  39.0   16.0
# 2018-03-04 23:50:00  43.0  43.0  57.0  112.0  39.0   11.0
# 2018-03-04 23:55:00  46.0  38.0  58.0   98.0  42.0   12.0
#
# [57600 rows x 6 columns]

# %% [markdown]
# # Urban Expressway

# %% [markdown]
# Oakland CA; Total length = 2,242.16m

# %% [markdown]
# ![Oakland_Large.PNG](attachment:Oakland_Large.PNG)

# %% [markdown]
# # Correlations

# %% [markdown]
# ### (ii) Day pattern (mon - fri)

# %% [markdown]
# ### Week 1

# %%
df = TrainVal['f4'][(TrainVal.index.month == 8)]


df1 = df[df.index.day == 21].reset_index(drop=True)
df2 = df[df.index.day == 22].reset_index(drop=True)
df3 = df[df.index.day == 23].reset_index(drop=True)
df4 = df[df.index.day == 24].reset_index(drop=True)
df5 = df[df.index.day == 25].reset_index(drop=True)
#df6 = df[df.index.day == 26].reset_index(drop=True)
#df7 = df[df.index.day == 27].reset_index(drop=True)


wk1 = pd.DataFrame([df1,df2,df3,df4,df5]).T #,df6,df7]).T
wk1.columns = ['Mon','Tue','Wed','Thu','Fri'] #,'Sat','Sun']

# %%
# The above as a plot

wk1 = wk1.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk1, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk1, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### Week 2

# %%
df = TrainVal['f4'][(TrainVal.index.month == 8)]

df1 = df[df.index.day == 28].reset_index(drop=True)
df2 = df[df.index.day == 29].reset_index(drop=True)
df3 = df[df.index.day == 30].reset_index(drop=True)
df4 = df[df.index.day == 31].reset_index(drop=True)



df = TrainVal['f4'][(TrainVal.index.month == 9)]

df5 = df[df.index.day == 1].reset_index(drop=True)
#df6 = df[df.index.day == 2].reset_index(drop=True)
#df7 = df[df.index.day == 3].reset_index(drop=True)


wk2 = pd.DataFrame([df1,df2,df3,df4,df5]).T #,df6,df7]).T
wk2.columns = ['Mon','Tue','Wed','Thu','Fri'] #,'Sat','Sun']

# %%
# The above as a plot

wk2 = wk2.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk2, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk2, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### Week 3

# %%
df = TrainVal['f4'][(TrainVal.index.month == 9)]


df1 = df[df.index.day == 4].reset_index(drop=True)
df2 = df[df.index.day == 5].reset_index(drop=True)
df3 = df[df.index.day == 6].reset_index(drop=True)
df4 = df[df.index.day == 7].reset_index(drop=True)
df5 = df[df.index.day == 8].reset_index(drop=True)
#df6 = df[df.index.day == 9].reset_index(drop=True)
#df7 = df[df.index.day == 10].reset_index(drop=True)


wk3 = pd.DataFrame([df1,df2,df3,df4,df5]).T #,df6,df7]).T
wk3.columns = ['Mon','Tue','Wed','Thu','Fri'] #,'Sat','Sun']

# %%
# The above as a plot

wk3 = wk3.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk3, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk3, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### Week 4

# %%
df = TrainVal['f4'][(TrainVal.index.month == 9)]


df1 = df[df.index.day == 11].reset_index(drop=True)
df2 = df[df.index.day == 12].reset_index(drop=True)
df3 = df[df.index.day == 13].reset_index(drop=True)
df4 = df[df.index.day == 14].reset_index(drop=True)
df5 = df[df.index.day == 15].reset_index(drop=True)
#df6 = df[df.index.day == 16].reset_index(drop=True)
#df7 = df[df.index.day == 17].reset_index(drop=True)


wk4 = pd.DataFrame([df1,df2,df3,df4,df5]).T #,df6,df7]).T
wk4.columns = ['Mon','Tue','Wed','Thu','Fri'] #,'Sat','Sun']

# %%
# The above as a plot

wk4 = wk4.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk4, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk4, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### Week 5

# %%
df = TrainVal['f4'][(TrainVal.index.month == 9)]


df1 = df[df.index.day == 18].reset_index(drop=True)
df2 = df[df.index.day == 19].reset_index(drop=True)
df3 = df[df.index.day == 20].reset_index(drop=True)
df4 = df[df.index.day == 21].reset_index(drop=True)
df5 = df[df.index.day == 22].reset_index(drop=True)
#df6 = df[df.index.day == 23].reset_index(drop=True)
#df7 = df[df.index.day == 24].reset_index(drop=True)


wk5 = pd.DataFrame([df1,df2,df3,df4,df5]).T #,df6,df7]).T
wk5.columns = ['Mon','Tue','Wed','Thu','Fri'] #,'Sat','Sun']

# %%
# The above as a plot

wk5 = wk5.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk5, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk5, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### Results (Mon - Fri)

# %%
data = [wk1,wk2,wk3,wk4,wk5]

# %%
day = pd.concat(data)

# %%
day.reset_index(drop=True,inplace=True)

# %%
day
# Out:
#          Mon       Tue       Wed       Thu       Fri
# 0   1.000000  0.949538  0.944683  0.955292  0.921797
# 1   0.949538  1.000000  0.967082  0.970293  0.953819
# 2   0.944683  0.967082  1.000000  0.972650  0.958532
# 3   0.955292  0.970293  0.972650  1.000000  0.957253
# 4   0.921797  0.953819  0.958532  0.957253  1.000000
# 5   1.000000  0.971096  0.954907  0.949739  0.930559
# 6   0.971096  1.000000  0.961030  0.955820  0.932216
# 7   0.954907  0.961030  1.000000  0.943144  0.915479
# 8   0.949739  0.955820  0.943144  1.000000  0.954889
# 9   0.930559  0.932216  0.915479  0.954889  1.000000
# 10  1.000000  0.888467  0.885118  0.901770  0.912580
# 11  0.888467  1.000000  0.970680  0.970132  0.962864
# 12  0.885118  0.970680  1.000000  0.967245  0.957182
# 13  0.901770  0.970132  0.967245  1.000000  0.971394
# 14  0.912580  0.962864  0.957182  0.971394  1.000000
# 15  1.000000  0.977493  0.965197  0.965067  0.949491
# 16  0.977493  1.000000  0.967243  0.968656  0.950629
# 17  0.965197  0.967243  1.000000  0.963877  0.953349
# 18  0.965067  0.968656  0.963877  1.000000  0.956955
# 19  0.949491  0.950629  0.953349  0.956955  1.000000
# 20  1.000000  0.974243  0.938414  0.950932  0.932369
# 21  0.974243  1.000000  0.930075  0.963429  0.947738
# 22  0.938414  0.930075  1.000000  0.900802  0.882454
# 23  0.950932  0.963429  0.900802  1.000000  0.960721
# 24  0.932369  0.947738  0.882454  0.960721  1.000000

# %%
day.keys()
# Out:
# Index(['Mon', 'Tue', 'Wed', 'Thu', 'Fri'], dtype='object')

# %% [markdown]
# ### Weekday

# %%
day[['Mon', 'Tue', 'Wed', 'Thu', 'Fri']].min().min()
# Out:
# 0.8824538830274055

# %%
day[['Mon', 'Tue', 'Wed', 'Thu', 'Fri']].mean().mean()
# Out:
# 0.9585021121233259

# %%
day[['Mon', 'Tue', 'Wed', 'Thu', 'Fri']].max().max()
# Out:
# 1.0

# %%
day['Mon'].nlargest(6)
# Out:
# 0     1.000000
# 5     1.000000
# 10    1.000000
# 15    1.000000
# 20    1.000000
# 16    0.977493
# Name: Mon, dtype: float64

# %%
day[['Mon', 'Tue', 'Wed', 'Thu', 'Fri']].std().mean()
# Out:
# 0.029829834338667528

# %% [markdown]
# ### Weekend

# %%
df = TrainVal['f4'][(TrainVal.index.month == 8)]


df6 = df[df.index.day == 26].reset_index(drop=True)
df7 = df[df.index.day == 27].reset_index(drop=True)


wk1 = pd.DataFrame([df6,df7]).T
wk1.columns = ['Sat','Sun']

# %%
# The above as a plot

wk1 = wk1.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk1, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk1, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %%
df = TrainVal['f4'][(TrainVal.index.month == 9)]


df6 = df[df.index.day == 2].reset_index(drop=True)
df7 = df[df.index.day == 3].reset_index(drop=True)


wk2 = pd.DataFrame([df6,df7]).T
wk2.columns = ['Sat','Sun']

# %%
# The above as a plot

wk2 = wk2.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk2, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk2, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %%
df = TrainVal['f4'][(TrainVal.index.month == 9)]


df6 = df[df.index.day == 9].reset_index(drop=True)
df7 = df[df.index.day == 10].reset_index(drop=True)


wk3 = pd.DataFrame([df6,df7]).T
wk3.columns = ['Sat','Sun']

# %%
# The above as a plot

wk3 = wk3.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk3, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk3, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %%
df = TrainVal['f4'][(TrainVal.index.month == 9)]


df6 = df[df.index.day == 16].reset_index(drop=True)
df7 = df[df.index.day == 17].reset_index(drop=True)


wk4 = pd.DataFrame([df6,df7]).T
wk4.columns = ['Sat','Sun']

# %%
# The above as a plot

wk4 = wk4.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk4, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk4, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %%
df = TrainVal['f4'][(TrainVal.index.month == 9)]


df6 = df[df.index.day == 23].reset_index(drop=True)
df7 = df[df.index.day == 24].reset_index(drop=True)


wk5 = pd.DataFrame([df6,df7]).T
wk5.columns = ['Sat','Sun']

# %%
# The above as a plot

wk5 = wk5.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk5, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk5, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %%
data = [wk1,wk2,wk3,wk4,wk5]

# %%
day = pd.concat(data)

# %%
day.reset_index(drop=True,inplace=True)

# %%
day
# Out:
#         Sat       Sun
# 0  1.000000  0.926569
# 1  0.926569  1.000000
# 2  1.000000  0.931959
# 3  0.931959  1.000000
# 4  1.000000  0.936545
# 5  0.936545  1.000000
# 6  1.000000  0.930401
# 7  0.930401  1.000000
# 8  1.000000  0.902753
# 9  0.902753  1.000000

# %%
day[['Sat', 'Sun']].min().min()
# Out:
# 0.9027530211451321

# %%
day[['Sat', 'Sun']].mean().mean()
# Out:
# 0.9628227870238519

# %%
day[['Sat', 'Sun']].max().max()
# Out:
# 1.0

# %%
day['Sat'].nlargest(6)
# Out:
# 0    1.000000
# 2    1.000000
# 4    1.000000
# 6    1.000000
# 8    1.000000
# 5    0.936545
# Name: Sat, dtype: float64

# %%
day[['Sat', 'Sun']].std().mean()
# Out:
# 0.04017690358812314
