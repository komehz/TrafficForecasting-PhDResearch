# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read saved csv files
TrainVal     = pd.read_csv('0TrainVal.csv',index_col=0,parse_dates=True)

# %%
TrainVal
# Out:
#                        f1    f2    f3     f4    f5     f6
# Timestamp
# 2017-08-17 00:00:00  46.0  38.0  43.9  121.0  65.0   87.0
# 2017-08-17 00:05:00  37.0  37.0  52.9  109.0  60.0   90.0
# 2017-08-17 00:10:00  45.0  43.0  39.0  105.0  61.0   87.0
# 2017-08-17 00:15:00  38.0  35.0  36.2  109.0  68.0  102.0
# 2017-08-17 00:20:00  36.0  30.0  30.0   94.0  61.0   93.0
# ...                   ...   ...   ...    ...   ...    ...
# 2018-03-04 23:35:00  46.0  41.0  70.0  118.0  64.0   52.0
# 2018-03-04 23:40:00  39.0  37.0  53.0   93.0  43.0   28.0
# 2018-03-04 23:45:00  48.0  54.0  45.0   94.0  39.0   16.0
# 2018-03-04 23:50:00  43.0  43.0  57.0  112.0  39.0   11.0
# 2018-03-04 23:55:00  46.0  38.0  58.0   98.0  42.0   12.0
#
# [57600 rows x 6 columns]

# %% [markdown]
# # Urban Expressway

# %% [markdown]
# Oakland CA; Total length = 2,242.16m

# %% [markdown]
# ![Oakland_Large.PNG](attachment:Oakland_Large.PNG)

# %% [markdown]
# # Correlations

# %% [markdown]
# ### (i) Week pattern (mon - mon)

# %%
df = TrainVal['f3'][(TrainVal.index.dayofweek == 0)][:12960]


df1 = df[df.index.day == 21].reset_index(drop=True)
df2 = df[df.index.day == 28].reset_index(drop=True)
df3 = df[df.index.day == 4].reset_index(drop=True)
df4 = df[df.index.day == 11].reset_index(drop=True)
df5 = df[df.index.day == 18].reset_index(drop=True)


mon = pd.DataFrame([df1,df2,df3,df4,df5]).T
mon.columns = [1,2,3,4,5]

# %%
# The above as a plot

Mon = mon.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(Mon, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(Mon, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### (b) Week pattern (Tue - Tue)

# %%
df = TrainVal['f3'][(TrainVal.index.dayofweek == 1)][:12960]


df1 = df[df.index.day == 22].reset_index(drop=True)
df2 = df[df.index.day == 29].reset_index(drop=True)
df3 = df[df.index.day == 5].reset_index(drop=True)
df4 = df[df.index.day == 12].reset_index(drop=True)
df5 = df[df.index.day == 19].reset_index(drop=True)


tue = pd.DataFrame([df1,df2,df3,df4,df5]).T
tue.columns = [1,2,3,4,5]

# %%
# The above as a plot

Tue = tue.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(Tue, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(Tue, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### (c) Week pattern (Wed - Wed)

# %%
df = TrainVal['f3'][(TrainVal.index.dayofweek == 2)][:12960]


df1 = df[df.index.day == 23].reset_index(drop=True)
df2 = df[df.index.day == 30].reset_index(drop=True)
df3 = df[df.index.day == 6].reset_index(drop=True)
df4 = df[df.index.day == 13].reset_index(drop=True)
df5 = df[df.index.day == 20].reset_index(drop=True)


wed = pd.DataFrame([df1,df2,df3,df4,df5]).T
wed.columns = [1,2,3,4,5]

# %%
# The above as a plot

Wed = wed.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(Wed, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(Wed, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### (d) Week pattern (Thur - Thur)

# %%
df = TrainVal['f3'][(TrainVal.index.dayofweek == 3)][:12960]


df1 = df[df.index.day == 24].reset_index(drop=True)
df2 = df[df.index.day == 31].reset_index(drop=True)
df3 = df[df.index.day == 7].reset_index(drop=True)
df4 = df[df.index.day == 14].reset_index(drop=True)
df5 = df[df.index.day == 21].reset_index(drop=True)


thur = pd.DataFrame([df1,df2,df3,df4,df5]).T
thur.columns = [1,2,3,4,5]

# %%
# The above as a plot

Thur = thur.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(Thur, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(Thur, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### (e) Week pattern (Fri - Fri)

# %%
df = TrainVal['f3'][(TrainVal.index.dayofweek == 4)][:12960]


df1 = df[df.index.day == 25].reset_index(drop=True)
df2 = df[df.index.day == 1].reset_index(drop=True)
df3 = df[df.index.day == 8].reset_index(drop=True)
df4 = df[df.index.day == 15].reset_index(drop=True)
df5 = df[df.index.day == 22].reset_index(drop=True)


fri = pd.DataFrame([df1,df2,df3,df4,df5]).T
fri.columns = [1,2,3,4,5]

# %%
# The above as a plot

Fri = fri.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(Fri, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(Fri, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### (f) Week pattern (Sat - Sat)

# %%
df = TrainVal['f3'][(TrainVal.index.dayofweek == 5)][:12960]


df1 = df[df.index.day == 26].reset_index(drop=True)
df2 = df[df.index.day == 2].reset_index(drop=True)
df3 = df[df.index.day == 9].reset_index(drop=True)
df4 = df[df.index.day == 16].reset_index(drop=True)
df5 = df[df.index.day == 23].reset_index(drop=True)


sat = pd.DataFrame([df1,df2,df3,df4,df5]).T
sat.columns = [1,2,3,4,5]

# %%
# The above as a plot

Sat = sat.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(Sat, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(Sat, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### (g) Week pattern (Sun - Sun)

# %%
df = TrainVal['f3'][(TrainVal.index.dayofweek == 6)][:12960]


df1 = df[df.index.day == 27].reset_index(drop=True)
df2 = df[df.index.day == 3].reset_index(drop=True)
df3 = df[df.index.day == 10].reset_index(drop=True)
df4 = df[df.index.day == 17].reset_index(drop=True)
df5 = df[df.index.day == 24].reset_index(drop=True)


sun = pd.DataFrame([df1,df2,df3,df4,df5]).T
sun.columns = [1,2,3,4,5]

# %%
# The above as a plot

Sun = sun.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(Sun, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(Sun, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### Results (Day - Day)

# %%
data = [Mon,Tue,Wed,Thur,Fri,Sat,Sun]

# %%
day_day = pd.concat(data)

# %%
day_day.reset_index(drop=True,inplace=True)

# %%
day_day
# Out:
#            1         2         3         4         5
# 0   1.000000  0.933469  0.826270  0.938770  0.939421
# 1   0.933469  1.000000  0.894528  0.964114  0.971224
# 2   0.826270  0.894528  1.000000  0.901442  0.892144
# 3   0.938770  0.964114  0.901442  1.000000  0.962787
# 4   0.939421  0.971224  0.892144  0.962787  1.000000
# 5   1.000000  0.968885  0.961761  0.960396  0.959889
# 6   0.968885  1.000000  0.965237  0.965246  0.972937
# 7   0.961761  0.965237  1.000000  0.967076  0.964454
# 8   0.960396  0.965246  0.967076  1.000000  0.961765
# 9   0.959889  0.972937  0.964454  0.961765  1.000000
# 10  1.000000  0.964477  0.962346  0.956696  0.957492
# 11  0.964477  1.000000  0.960847  0.959234  0.961122
# 12  0.962346  0.960847  1.000000  0.962751  0.956844
# 13  0.956696  0.959234  0.962751  1.000000  0.959275
# 14  0.957492  0.961122  0.956844  0.959275  1.000000
# 15  1.000000  0.944995  0.963806  0.967450  0.968765
# 16  0.944995  1.000000  0.937985  0.933221  0.939207
# ...

# %%
day_day.min().min()
# Out:
# 0.82627015131878

# %%
day_day.mean().mean()
# Out:
# 0.956031000496756

# %%
day_day.max().max() #0.98 from observation
# Out:
# 1.0

# %%
day_day[1].nlargest(8)
# Out:
# 0     1.000000
# 5     1.000000
# 10    1.000000
# 15    1.000000
# 20    1.000000
# 25    1.000000
# 30    1.000000
# 6     0.968885
# Name: 1, dtype: float64

# %%
day_day.std().mean()
# Out:
# 0.0319319570371742

# %% [markdown]
# ### (ii) Day pattern (mon - fri)

# %% [markdown]
# ### Week 1

# %%
df = TrainVal['f3'][(TrainVal.index.month == 8)]


df1 = df[df.index.day == 21].reset_index(drop=True)
df2 = df[df.index.day == 22].reset_index(drop=True)
df3 = df[df.index.day == 23].reset_index(drop=True)
df4 = df[df.index.day == 24].reset_index(drop=True)
df5 = df[df.index.day == 25].reset_index(drop=True)
df6 = df[df.index.day == 26].reset_index(drop=True)
df7 = df[df.index.day == 27].reset_index(drop=True)


wk1 = pd.DataFrame([df1,df2,df3,df4,df5,df6,df7]).T
wk1.columns = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

# %%
# The above as a plot

wk1 = wk1.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk1, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk1, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### Week 2

# %%
df = TrainVal['f3'][(TrainVal.index.month == 8)]

df1 = df[df.index.day == 28].reset_index(drop=True)
df2 = df[df.index.day == 29].reset_index(drop=True)
df3 = df[df.index.day == 30].reset_index(drop=True)
df4 = df[df.index.day == 31].reset_index(drop=True)



df = TrainVal['f3'][(TrainVal.index.month == 9)]

df5 = df[df.index.day == 1].reset_index(drop=True)
df6 = df[df.index.day == 2].reset_index(drop=True)
df7 = df[df.index.day == 3].reset_index(drop=True)


wk2 = pd.DataFrame([df1,df2,df3,df4,df5,df6,df7]).T
wk2.columns = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

# %%
# The above as a plot

wk2 = wk2.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk2, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk2, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### Week 3

# %%
df = TrainVal['f3'][(TrainVal.index.month == 9)]


df1 = df[df.index.day == 4].reset_index(drop=True)
df2 = df[df.index.day == 5].reset_index(drop=True)
df3 = df[df.index.day == 6].reset_index(drop=True)
df4 = df[df.index.day == 7].reset_index(drop=True)
df5 = df[df.index.day == 8].reset_index(drop=True)
df6 = df[df.index.day == 9].reset_index(drop=True)
df7 = df[df.index.day == 10].reset_index(drop=True)


wk3 = pd.DataFrame([df1,df2,df3,df4,df5,df6,df7]).T
wk3.columns = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

# %%
# The above as a plot

wk3 = wk3.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk3, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk3, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### Week 4

# %%
df = TrainVal['f3'][(TrainVal.index.month == 9)]


df1 = df[df.index.day == 11].reset_index(drop=True)
df2 = df[df.index.day == 12].reset_index(drop=True)
df3 = df[df.index.day == 13].reset_index(drop=True)
df4 = df[df.index.day == 14].reset_index(drop=True)
df5 = df[df.index.day == 15].reset_index(drop=True)
df6 = df[df.index.day == 16].reset_index(drop=True)
df7 = df[df.index.day == 17].reset_index(drop=True)


wk4 = pd.DataFrame([df1,df2,df3,df4,df5,df6,df7]).T
wk4.columns = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

# %%
# The above as a plot

wk4 = wk4.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk4, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk4, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### Week 5

# %%
df = TrainVal['f3'][(TrainVal.index.month == 9)]


df1 = df[df.index.day == 18].reset_index(drop=True)
df2 = df[df.index.day == 19].reset_index(drop=True)
df3 = df[df.index.day == 20].reset_index(drop=True)
df4 = df[df.index.day == 21].reset_index(drop=True)
df5 = df[df.index.day == 22].reset_index(drop=True)
df6 = df[df.index.day == 23].reset_index(drop=True)
df7 = df[df.index.day == 24].reset_index(drop=True)


wk5 = pd.DataFrame([df1,df2,df3,df4,df5,df6,df7]).T
wk5.columns = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

# %%
# The above as a plot

wk5 = wk5.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(wk5, dtype=bool), 1)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 9))

# Draw the heatmap with the mask and correct aspect ratio
crr = sns.heatmap(wk5, mask=mask, cmap="rocket_r", fmt='.2g',
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

crr.set_yticklabels(crr.get_yticklabels(), rotation=0);

# %% [markdown]
# ### Results (Mon - Fri)

# %%
data = [wk1,wk2,wk3,wk4,wk5]

# %%
day = pd.concat(data)

# %%
day.reset_index(drop=True,inplace=True)

# %%
day
# Out:
#          Mon       Tue       Wed       Thu       Fri       Sat       Sun
# 0   1.000000  0.928186  0.923049  0.931477  0.899459  0.843123  0.813208
# 1   0.928186  1.000000  0.961281  0.960804  0.948190  0.907312  0.892956
# 2   0.923049  0.961281  1.000000  0.963550  0.956575  0.906258  0.888076
# 3   0.931477  0.960804  0.963550  1.000000  0.961803  0.905944  0.890879
# 4   0.899459  0.948190  0.956575  0.961803  1.000000  0.925649  0.892034
# 5   0.843123  0.907312  0.906258  0.905944  0.925649  1.000000  0.944584
# 6   0.813208  0.892956  0.888076  0.890879  0.892034  0.944584  1.000000
# 7   1.000000  0.963895  0.956610  0.916880  0.934400  0.861236  0.843207
# 8   0.963895  1.000000  0.964435  0.936258  0.936968  0.869402  0.858388
# 9   0.956610  0.964435  1.000000  0.935137  0.938036  0.870205  0.870204
# 10  0.916880  0.936258  0.935137  1.000000  0.935868  0.844239  0.830598
# 11  0.934400  0.936968  0.938036  0.935868  1.000000  0.904638  0.870335
# ...

# %%
day.min().min()
# Out:
# 0.8132079954078824

# %%
day.mean().mean()
# Out:
# 0.9250721167897996

# %%
day.max().max()
# Out:
# 1.0

# %%
day['Mon'].nlargest(6)
# Out:
# 0     1.000000
# 7     1.000000
# 14    1.000000
# 21    1.000000
# 28    1.000000
# 30    0.966805
# Name: Mon, dtype: float64

# %%
day.std().mean()
# Out:
# 0.045357924970420585
